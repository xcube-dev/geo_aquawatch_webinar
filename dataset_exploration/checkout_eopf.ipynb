# %%
from xcube.core.store import new_data_store

# %%
store = new_data_store("eopf-zarr")

# %%
store.list_data_ids()
# Out:
# ['sentinel-2-l1c',
#  'sentinel-2-l2a',
#  'sentinel-3-olci-l1-efr',
#  'sentinel-3-olci-l2-lfr',
#  'sentinel-3-slstr-l2-lst']

# %%
ds = store.open_data(
    "sentinel-2-l2a",
    time_range=("2025-06-01", "2025-12-31"),
    bbox=[4.41, 59.94, 6.23, 60.84],
    spatial_res=0.0001,
    crs="EPSG:4326",
)
ds
