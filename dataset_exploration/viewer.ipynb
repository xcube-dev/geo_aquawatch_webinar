# %%
from xcube.core.store import new_data_store
from xcube.webapi.viewer import Viewer
from xcube.util.config import load_configs

# %% [markdown]
# ---
# ## Access data from Team Storage

# %%
team_store = new_data_store(
    "s3", 
    root="hub-deepesdl58", 
    storage_options=dict(
        anon=False, 
        key="AKIAYCYVXVE3CAE2QE6S", 
        secret="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"
    )
)

# %%
data_ids = team_store.list_data_ids()
data_ids
# Out:
# ['oc_cci.zarr',
#  'oc_glo_cmems_300m.zarr',
#  'oc_glo_cmems_4km.zarr',
#  'oc_nws_cmems.levels',
#  'oc_nws_cmems.zarr',
#  'sen2_l2a.levels',
#  'sen2l2a.levels',
#  'sen2l2a0.levels',
#  'sen2l2a2.levels',
#  'sen2l2a3.levels',
#  'sen2l2a_stavanger_large0.zarr',
#  'sen2l2a_stavanger_large2.zarr',
#  'sen2l2a_stavanger_large3.zarr']

# %% [markdown]
# ---
# ## Vizualize Data in xcube Viewer

# %%
viewer = Viewer(server_config=load_configs("server-config.yaml"))
# Out:
# 404 GET /viewer/config/config.json (127.0.0.1): xcube viewer has not been been configured
# 404 GET /viewer/config/config.json (127.0.0.1) 5.25ms
# 501 GET /viewer/state?key=sentinel (127.0.0.1) 0.40ms
# 404 GET /viewer/ext/contributions (127.0.0.1) 70.02ms
# /home/conda/users/f749afb9-1764838744-170-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/store/fs/store.py:668: UserWarning: No data opener found for format 'zarr' and data type 'mldataset'. Data type is changed to the default data type 'dataset'.
#   warnings.warn(
# /home/conda/users/f749afb9-1764838744-170-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/store/fs/store.py:668: UserWarning: No data opener found for format 'zarr' and data type 'mldataset'. Data type is changed to the default data type 'dataset'.
#   warnings.warn(
# /home/conda/users/f749afb9-1764838744-170-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/store/fs/store.py:668: UserWarning: No data opener found for format 'zarr' and data type 'mldataset'. Data type is changed to the default data type 'dataset'.
#   warnings.warn(
# /home/conda/users/f749afb9-1764838744-170-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/store/fs/store.py:668: UserWarning: No data opener found for format 'zarr' and data type 'mldataset'. Data type is changed to the default data type 'dataset'.
#   warnings.warn(
# 404 GET /tiles/sen2l2a_cube/rgb/8/76/131?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1): Variable 'B04_mean' not found in dataset 'sen2l2a_cube'
# 404 GET /tiles/sen2l2a_cube/rgb/8/76/131?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1) 4.79ms
# 404 GET /tiles/sen2l2a_cube/rgb/8/76/132?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1): Variable 'B04_mean' not found in dataset 'sen2l2a_cube'
# 404 GET /tiles/sen2l2a_cube/rgb/8/76/132?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1) 3.12ms
# 404 GET /tiles/sen2l2a_cube/rgb/8/75/131?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1): Variable 'B04_mean' not found in dataset 'sen2l2a_cube'
# 404 GET /tiles/sen2l2a_cube/rgb/8/75/131?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1) 6.09ms
# 404 GET /tiles/sen2l2a_cube/rgb/8/75/132?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1): Variable 'B04_mean' not found in dataset 'sen2l2a_cube'
# 404 GET /tiles/sen2l2a_cube/rgb/8/75/132?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1) 4.62ms
# 404 GET /tiles/sen2l2a_cube/rgb/8/77/131?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1): Variable 'B04_mean' not found in dataset 'sen2l2a_cube'
# 404 GET /tiles/sen2l2a_cube/rgb/8/77/131?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1) 6.53ms
# 404 GET /tiles/sen2l2a_cube/rgb/8/77/132?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1): Variable 'B04_mean' not found in dataset 'sen2l2a_cube'
# 404 GET /tiles/sen2l2a_cube/rgb/8/77/132?crs=EPSG%3A3857&time=2023-06-30T00%3A00%3A00Z (127.0.0.1) 8.88ms

# %%
viewer.info()
# Out:
# Server: https://deep.earthsystemdatalab.net/user/clarasb/proxy/8001
# Viewer: https://deep.earthsystemdatalab.net/user/clarasb/proxy/8001/viewer/?serverUrl=https://deep.earthsystemdatalab.net/user/clarasb/proxy/8001

# %%
viewer.show()
# Out:
# <iframe src="https://deep.earthsystemdatalab.net/user/clarasb/proxy/8000/viewer/?serverUrl=https://deep.earthsystemdatalab.net/user/clarasb/proxy/8000&compact=0" width="100%" height="800"/>
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:518: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 0] = (255 * r).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:519: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 1] = (255 * g).astype(np.uint8)
# /home/conda/users/30f6ffd2-1762860680-159-deepesdl-xcube-1.12.0/lib/python3.13/site-packages/xcube/core/tile.py:520: RuntimeWarning: invalid value encountered in cast
#   var_tile_rgba[:, :, 2] = (255 * b).astype(np.uint8)

# %%
viewer.stop_server()

# %% [markdown]
# ---

# %%
#team_store.delete_data("cmems_4km.zarr")
