# %%
import re

from xcube.core.store import new_data_store
import xarray as xr

# %%
cmems_store =  new_data_store("cmems")

# %% [markdown]
# Get all the data ids in cmems datastore

# %%
all_data_ids = list(cmems_store.get_data_ids())
len(all_data_ids)
# Out:
# 1256

# %%
[d for d in all_data_ids if re.search("oc.*nws.*geophy.*l4.*", d)]
# Out:
# ['cmems_obs_oc_nws_bgc_geophy_nrt_l4-hr_P1D-m',
#  'cmems_obs_oc_nws_bgc_geophy_nrt_l4-hr_P1M-m']

# %%
ds = cmems_store.open_data('cmems_obs_oc_nws_bgc_geophy_nrt_l4-hr_P1D-m')
ds
# Out:
# INFO - 2025-12-02T09:44:45Z - Selected dataset version: "202105"
# INFO - 2025-12-02T09:44:45Z - Selected dataset part: "default"
# An unexpected error occurred: No service available for dataset with command open_dataset
